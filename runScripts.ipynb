# %%
import sys
import os
print(sys.path)
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

if os.getcwd() + '/drive/My Drive/myRepository' not in sys.path:
  sys.path.append(os.getcwd() + '/My Drive/myRepository')
# Out:
# ['/content', '/env/python', '/usr/lib/python310.zip', '/usr/lib/python3.10', '/usr/lib/python3.10/lib-dynload', '', '/usr/local/lib/python3.10/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.10/dist-packages/IPython/extensions', '/root/.ipython', '/content/My Drive/myRepository']
# Mounted at /content/drive

# %%
# !python "/content/drive/My Drive/myRepository/training.py"  --nLayers 3 --batchSize 16 --usedProcessor 'cuda' --savePath "/content/drive/MyDrive/myRepository/savedModels/"
# Out:
# length of raw dataset: 1,115,394
# starting training with parameters:  Namespace(batchSize=16, blockSize=16, learningRate=0.001, epochs=20, parallelHeads=8, nLayers=3, channelsWanted=64, dff=128, softmax=False, usedProcessor='cuda', savePath='/content/drive/MyDrive/myRepository/savedModels/')
# epoch: 0 training loss: 3.4327645301818848
# epoch: 0 training loss: 2.842801809310913
# epoch: 0 training loss: 2.7093605995178223
# epoch: 0 training loss: 2.4585816860198975
# epoch: 0 training loss: 2.4955432415008545
# model saved in /content/drive/MyDrive/myRepository/savedModels/model_20230830030725.pth
# validation set:
# validation loss:  tensor(2.7120, device='cuda:0')
# validation loss:  tensor(2.4423, device='cuda:0')
# validation loss:  tensor(2.6315, device='cuda:0')
# validation loss:  tensor(2.4605, device='cuda:0')
# epoch: 0 training loss: 2.4777345657348633
# epoch: 0 training loss: 2.292464017868042
# epoch: 0 training loss: 2.3591482639312744
# ...

# %%
# !python "/content/drive/My Drive/myRepository/generation.py" --modelPath "/content/drive/My Drive/myRepository/savedModels/sampleModelCuda3LayersBatch16.pth" --usedProcessor 'cuda'
# Out:
# length of raw dataset: 1,115,394
# loading with parameters:  Namespace(outputSize=5000, modelPath='/content/drive/My Drive/myRepository/savedModels/sampleModelCuda3LayersBatch16.pth', usedProcessor='cuda')
# /content/drive/My Drive/myRepository/generation.py:51: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   loss, outputLogits = finalTransformer(torch.tensor(inferenceData).unsqueeze(0).to(device = processor), torch.tensor(inferenceData).unsqueeze(0).to(device = processor), gPos, training=False, softmax=False)
# /content/drive/My Drive/myRepository/generation.py:62: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# ...
